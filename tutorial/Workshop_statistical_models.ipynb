# %% [markdown]
# # Workshop: Modeling the Effect of Lifestyle Factors on Academic Performance

# %% [markdown]
# Can we explain student academic performance using lifestyle variables such as study time, sleep, and social habits?
#
# In this workshop, we will:
# *   Explore a real-world student lifestyle dataset
# *   Specify a statistical model
# *   Fit a linear regression model
# *   Interpret results
# *   Check key model assumptions

# %% [markdown]
# ## 1.Setup

# %% [markdown]
# ### Note on data loading
# - If working **locally**: make sure the CSV file is in the same folder as this notebook.
# - If working in **Google Colab**: upload the CSV file when prompted.

# %%
import pandas as pd

df = pd.read_csv("student_lifestyle_dataset.csv")
df.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#     GPA Stress_Level
# 0  2.99     Moderate
# 1  2.75          Low
# 2  2.67          Low
# 3  2.88     Moderate
# 4  3.51         High

# %% [markdown]
# ## 2.Exploratory Data Analysis

# %% [markdown]
# We start by exploring the dataset:
# - What variables are available?
# - Are there missing values?
# - Is GPA a continuous variable?

# %%
# TODO: Inspect the dataset

# %% [markdown]
# <details>
# <summary><b>Hint</b></summary>
#
# - Use `df.info()` to inspect column types
# - Use `df.describe()` to see summary statistics
#
# </details>

# %% [markdown]
# Now we think about:
#
#
# *   What is the dependent variable?
# *   Which variables could influence it?

# %% [markdown]
# <details>
# <summary><b>Hint</b></summary>
#
# Create scatterplots to explore relationships between GPA and:
# - Study hours per day
# - Sleep hours per day
# - Social hours per day
#
# Do these relationships appear linear?
#
# </details>

# %%
# TODO: Create scatterplots to explore relationship between variables
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# %% [markdown]
# <details>
# <summary><b>Hint</b></summary>
#
# - Use sns.scatterplot(x=..., y="GPA", data=df)
#
# </details>

# %% [markdown]
# ## 3.Model specification

# %% [markdown]
# We define:
# - **Dependent variable (Y):** GPA
# - **Independent variables (X):**
#   - Study_Hours_Per_Day
#   - Sleep_Hours_Per_Day
#   - Social_Hours_Per_Day
#
# We will use a **multiple linear regression model**.

# %%
# TODO: Specify X and y
import statsmodels.api as sm

X = df[

]

y =

# %% [markdown]
# <details>
# <summary><b>Hint</b></summary>
#
# - Select the relevant columns from df
# - Use sm.add_constant(X)
#
# </details>

# %% [markdown]
# ## 4. Fitting the model

# %% [markdown]
# Fit the linear regression model using Ordinary Least Squares (OLS)

# %%
# TODO: Fit the model
model =

# %% [markdown]
# <details>
# <summary><b>Hint</b></summary>
#
# - sm.OLS(y, X)
# - model.fit()
#
# </details>

# %% [markdown]
# Answer the following questions:
# - Which variable has the strongest effect on GPA?
# - Which effects are weak?
# - What does the R² value tell us in this context?

# %% [markdown]
# ## 5.Diagnostics & assumptions

# %% [markdown]
# We visually check:
# - Linearity
# - Homoscedasticity
# - Normality of residuals

# %%
# TODO: Residuals vs Fitted Values plot


plt.show()

# %% [markdown]
# <details>
# <summary><b>Hint</b></summary>
#
# - model.fittedvalues and model.resid
#
# </details>

# %%
# TODO: Q-Q plot of residuals


plt.show()

# %% [markdown]
# <details>
# <summary><b>Hint</b></summary>
#
# - sm.qqplot(..., line="45")
#
# </details>

# %% [markdown]
# ## 6.Wrap-up & reflection

# %% [markdown]
# Reflect on the following:
# - Is this model useful for explaining GPA?
# - What important factors are missing?
# - Would a more complex model be appropriate?
